# %% [markdown]
# <a href="https://colab.research.google.com/github/ydv-prince/EDA/blob/main/files_and_exception_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file = open("file1.txt", "w")

# %%
file.write("First line in file1.txt")
# Out:
# 23

# %%
file.close()

# %%
file
# Out:
# <_io.TextIOWrapper name='file1.txt' mode='w' encoding='UTF-8'>

# %%
file.name
# Out:
# 'file1.txt'

# %%
file.mode
# Out:
# 'w'

# %%
class Formatting:
  def Wrapper(func):
    print("Before Function")
    func()
    print("After Function")

def func():
  print("Hello World!!")

@Formatting
Wrapper(func())
# Out:
#   File "<ipython-input-4-b0d1f5735a38>", line 11
#     Wrapper(func())
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".

# %%
class Animal:
  def speak(self):
    print("Animal Voice")

class Dog(Animal):
  def speak(self):
    print("Dog barks")

# %%
a1 = Animal()
a1.speak()
# Out:
# Animal Voice

# %%
d1 = Dog()
d1.speak()
# Out:
# Dog barks

# %% [markdown]
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute

# %%
class Vehicle:
  def drive(self):
    print("Vehicle Started")

class Car(Vehicle):
  def color(self):
    print("Color of Car")

class ElectricCar(Car):
  def power(self):
    print("Runs on Electricity")

# %%
v1 = Vehicle()
v1.drive()
# Out:
# Vehicle Started

# %%
c1 = Car()
c1.color()
# Out:
# Color of Car

# %%
e1 = ElectricCar()
e1.power()
# Out:
# Runs on Electricity
